# %%
# %%capture
import pickle
import tqdm
#import pandas as pd
import networkx as nx
import cudf as pd
import nx_cugraph as cnx

# %%
# Set up folders
import os
if not os.path.exists('data'):
    os.makedirs('data')
if not os.path.exists('figs'):
    os.makedirs('figs')
if not os.path.exists('pickles'):
    os.makedirs('pickles')

# %%
def check_cached(path):
    if os.path.exists(path):
        return True
    return None

# %%
# Load data
df = pd.read_csv('data/SummaryIndividuals.csv')
df.head(5)
# Out:
#     ID  parent  created  lifeSpan  speed  maxEnergy  kidEnergy  sensors  \
# 0  355      12        0         2    2.0          3          4        5
# 1   82       2        0         2    2.0          4          1        5
# 2  100       2        0         2    2.0          3          1        5
# 3  108       2        0         2    2.0          3          1        5
# 4  114       2        0         2    2.0          3          1        5
#
#    ancestor  nkids  pgmDeath
# 0       355      2        20
# 1        82      3        20
# 2       100      3        20
# 3       108      3        20
# 4       114      3        20

# %%
# Create graph
G = nx.DiGraph(backend='cugraph')
G.add_edges_from(df.to_pandas()[['parent', 'ID']].itertuples(index=False), backend='cugraph')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 G = nx.DiGraph(backend='cugraph')
#       3 G.add_edges_from(df.to_pandas()[['parent', 'ID']].itertuples(index=False), backend='cugraph')
# ----> 4 print(nx.info(G, backend='cugraph'))
#
# AttributeError: module 'networkx' has no attribute 'info'

# %%
print(f'Number of nodes: {G.number_of_nodes()}')
print(f'Number of edges: {G.number_of_edges()}')
# Out:
# Number of nodes: 34112607
# Number of edges: 34112456

# %%
# Step 2: Find the longest path for each node
def longest_path_length(G, node):
    lengths = nx.single_source_dijkstra_path_length(G, node)
    return max(lengths.values()) if lengths else 0

path_cache = 'pickles/path_lengths.pkl'

if check_cached(path_cache) is None:
    print('Calculating path lengths')
    path_lengths = {node: longest_path_length(G, node) for node in tqdm.tqdm(G.nodes)}
    with tables.open_file(path_cache, mode='w') as f:
        pickle.dump(path_lengths, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    print('Loading path lengths')
    with tables.open_file(path_cache, mode='r') as f:
        path_lengths = pickle.load(f)
# Out:
# Calculating path lengths
# 100%|██████████| 34112607/34112607 [34:15<00:00, 16594.62it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       9     print('Calculating path lengths')
#      10     path_lengths = {node: longest_path_length(G, node) for node in tqdm.tqdm(G.nodes)}
# ---> 11     with tables.open_file(path_cache, mode='w') as f:
#      12         pickle.dump(path_lengths, f, protocol=pickle.HIGHEST_PROTOCOL)
#      13 else:
#
# NameError: name 'tables' is not defined

# %%
with open(path_cache, mode='wb') as f:
    pickle.dump(path_lengths, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Step 3: Sort nodes by path length and select the top 10%
top_10_cache = 'pickles/top_10_percent_nodes.pkl'

if check_cached(top_10_cache) is None:
    print('Sorting nodes')
    sorted_nodes = sorted(path_lengths, key=path_lengths.get, reverse=True)
    top_10_percent_length = int(len(sorted_nodes) * 0.1)
    top_10_percent_nodes = set(sorted_nodes[:top_10_percent_length])
    with open(top_10_cache, mode='wb') as f:
        pickle.dump(top_10_percent_nodes, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    print('Loading nodes')
    with open(top_10_cache, mode='rb') as f:
        top_10_percent_nodes = pickle.load(f)
# Out:
# Sorting nodes

# %%
# Step 4: Extract all nodes involved in these top 10% longest lineages
def extract_lineage_iterative(G, nodes):
    extracted = set()
    stack = list(nodes)
    
    while stack:
        node = stack.pop()
        if node not in G:
            extracted.add(node)
            continue
        extracted.add(node)
        stack.extend(G.successors(node))
    
    return extracted

lineage_cache = 'pickles/extracted_nodes.pkl'

# Load or compute the extracted nodes
if check_cached(lineage_cache) is None:
    print('Extracting lineages')
    extracted_nodes = set()
    for node in tqdm.tqdm(top_10_percent_nodes):
        extracted_nodes.update(extract_lineage_iterative(G, [node]))
    with open(lineage_cache, mode='wb') as f:
        pickle.dump(extracted_nodes, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    print('Loading lineages')
    with open(lineage_cache, mode='rb') as f:
        extracted_nodes = pickle.load(f)
# Out:
# Extracting lineages
# 100%|██████████| 3411260/3411260 [24:59<00:00, 2274.61it/s]

# %%
filtered_cache = 'data/filtered.csv'

if check_cached(filtered_cache) is not None:
    print('Loading filtered data')
    with open(filtered_cache, mode='r') as f:
        filtered_df = pd.read_csv(filtered_cache)
else:
    print('Creating filtered data')
    filtered_df = df[df['ID'].isin(extracted_nodes)]
    with open(filtered_cache, mode='w') as f:
        filtered_df.write_csv(filtered_cache, index=False)
# Out:
# Creating filtered data
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/cudf/utils/utils.py:227, in GetAttrGetItemMixin.__getattr__(self, key)
#     226 try:
# --> 227     return self[key]
#     228 except KeyError:
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     115 libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116 result = func(*args, **kwargs)
#     117 libnvtx_pop_range(self.domain.handle)
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/cudf/core/dataframe.py:1348, in DataFrame.__getitem__(self, arg)
#    1347 if _is_scalar_or_zero_d_array(arg) or isinstance(arg, tuple):
# -> 1348     return self._get_columns_by_label(arg, downcast=True)
#    1350 elif isinstance(arg, slice):
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     115 libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116 result = func(*args, **kwargs)
#     117 libnvtx_pop_range(self.domain.handle)
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/cudf/core/dataframe.py:2005, in DataFrame._get_columns_by_label(self, labels, downcast)
#    2000 """
#    2001 Return columns of dataframe by `labels`
#    2002
#    2003 If downcast is True, try and downcast from a DataFrame to a Series
#    2004 """
# -> 2005 ca = self._data.select_by_label(labels)
#    2006 if downcast:
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/cudf/core/column_accessor.py:399, in ColumnAccessor.select_by_label(self, key)
#     398         return self._select_by_label_with_wildcard(key)
# --> 399 return self._select_by_label_grouped(key)
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/cudf/core/column_accessor.py:546, in ColumnAccessor._select_by_label_grouped(self, key)
#     545 def _select_by_label_grouped(self, key: Any) -> ColumnAccessor:
# --> 546     result = self._grouped_data[key]
#     547     if isinstance(result, column.ColumnBase):
#     548         # self._grouped_data[key] = self._data[key] so skip validation
#
# KeyError: 'write_csv'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 11
#       9 filtered_df = df[df['ID'].isin(extracted_nodes)]
#      10 with open(filtered_cache, mode='w') as f:
# ---> 11     filtered_df.write_csv(filtered_cache, index=False)
#
# File ~/projects/tree-of-alife/.venv/lib/python3.10/site-packages/cudf/utils/utils.py:229, in GetAttrGetItemMixin.__getattr__(self, key)
#     227     return self[key]
#     228 except KeyError:
# --> 229     raise AttributeError(
#     230         f"{type(self).__name__} object has no attribute {key}"
#     231     )
#
# AttributeError: DataFrame object has no attribute write_csv
